# %% [markdown]
# # Model Training - 20 news dataset

# %% [markdown]
# ## Importing libraries

# %%
import pickle
from joblib import dump
from gensim import corpora, models

# %% [markdown]
# ## Load training data

# %%
preprocessed_text_path = "preprocessed_text/test_data7532"

# Load the array back
with open(f"{preprocessed_text_path}.pkl", 'rb') as f:
  preprocessed_docs = pickle.load(f)

# %%
author2doc_path = "preprocessed_text/author2doc-train"

with open(f"{author2doc_path}.pkl", 'rb') as f:
  author2doc = pickle.load(f)

# %% [markdown]
# ## Create Dictionary and Corpus
# Create a dictionary and Bag of Words (BoW) representation for the corpus.

# %%
dictionary = corpora.Dictionary(preprocessed_docs)

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_docs]

# %%
tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %% [markdown]
# ## Train Model

# %%
from pathlib import Path
import os
import sys

# %%
# Adjust the number of parent calls based on the nesting level
root_path = str(Path(os.getcwd()).resolve().parent)  
sys.path.append(root_path)

# %%
import model

# %%
# Initialize alpha, beta, a, and b if different from the defaults
alpha_init = 0.1
beta_init = 0.1
a_init = 0.1
b_init = 0.1

num_topics = 20

# %%
# Instantiate the ABLIMA model
trained_model = model.ABLIMA(
    corpus=corpus_tfidf,
    num_topics=num_topics,
    id2word=dictionary,
    authors=author2doc,
    alpha_init=alpha_init,
    beta_init=beta_init,
    a_init=a_init,
    b_init=b_init
)

# %%
# Run Gibbs sampling for training
trained_model.gibbs_sampling(iterations=200)
# Out:
# iteration: 1
# Time : 226.7683 seconds
#
# iteration: 2
# Time : 148.6863 seconds
#
# iteration: 3
# Time : 144.0710 seconds
#
# iteration: 4
# Time : 147.3567 seconds
#
# iteration: 5
# Time : 149.2424 seconds
#
# iteration: 6
# Time : 146.4978 seconds
#
# iteration: 7
# Time : 145.8733 seconds
#
# iteration: 8
# Time : 144.5982 seconds
#
# iteration: 9
# Time : 145.6026 seconds
#
# iteration: 10
# Time : 144.6232 seconds
#
# iteration: 11
# Time : 145.3878 seconds
#
# iteration: 12
# Time : 143.9943 seconds
#
# iteration: 13
# Time : 143.5315 seconds
#
# iteration: 14
# Time : 143.3523 seconds
#
# iteration: 15
# Time : 144.3344 seconds
#
# iteration: 16
# Time : 144.5447 seconds
#
# iteration: 17
# Time : 144.5858 seconds
#
# iteration: 18
# Time : 143.8310 seconds
#
# iteration: 19
# Time : 143.5389 seconds
#
# iteration: 20
# Time : 143.9356 seconds
#
# iteration: 21
# Time : 143.6863 seconds
#
# iteration: 22
# Time : 143.8888 seconds
#
# iteration: 23
# Time : 144.9950 seconds
#
# iteration: 24
# Time : 144.7465 seconds
#
# iteration: 25
# Time : 143.8804 seconds
#
# iteration: 26
# Time : 143.8844 seconds
#
# iteration: 27
# Time : 143.6162 seconds
#
# iteration: 28
# Time : 143.1086 seconds
#
# iteration: 29
# Time : 143.5197 seconds
#
# iteration: 30
# Time : 143.4914 seconds
#
# iteration: 31
# Time : 143.1310 seconds
#
# iteration: 32
# Time : 142.8904 seconds
#
# iteration: 33
# Time : 142.6797 seconds
#
# iteration: 34
# Time : 143.1747 seconds
#
# iteration: 35
# Time : 143.4520 seconds
#
# iteration: 36
# Time : 142.8512 seconds
#
# iteration: 37
# Time : 142.6221 seconds
#
# iteration: 38
# Time : 142.6272 seconds
#
# iteration: 39
# Time : 142.9829 seconds
#
# iteration: 40
# Time : 142.2673 seconds
#
# iteration: 41
# Time : 142.9123 seconds
#
# iteration: 42
# Time : 143.2737 seconds
#
# iteration: 43
# Time : 142.4078 seconds
#
# iteration: 44
# Time : 142.8538 seconds
#
# iteration: 45
# Time : 143.3618 seconds
#
# iteration: 46
# Time : 142.8293 seconds
#
# iteration: 47
# Time : 142.8564 seconds
#
# iteration: 48
# Time : 143.9074 seconds
#
# iteration: 49
# Time : 143.2194 seconds
#
# iteration: 50
# Time : 143.0532 seconds
#
# iteration: 51
# Time : 142.5916 seconds
#
# iteration: 52
# Time : 142.7387 seconds
#
# iteration: 53
# Time : 143.3700 seconds
#
# iteration: 54
# Time : 142.9939 seconds
#
# iteration: 55
# Time : 143.2859 seconds
#
# iteration: 56
# Time : 143.2806 seconds
#
# iteration: 57
# Time : 142.2074 seconds
#
# iteration: 58
# Time : 142.3809 seconds
#
# iteration: 59
# Time : 142.9961 seconds
#
# iteration: 60
# Time : 142.8605 seconds
#
# iteration: 61
# Time : 142.4536 seconds
#
# iteration: 62
# Time : 142.1354 seconds
#
# iteration: 63
# Time : 142.1533 seconds
#
# iteration: 64
# Time : 142.5809 seconds
#
# iteration: 65
# Time : 143.0393 seconds
#
# iteration: 66
# Time : 142.6299 seconds
#
# iteration: 67
# Time : 142.7825 seconds
#
# iteration: 68
# Time : 142.7956 seconds
#
# iteration: 69
# Time : 142.9187 seconds
#
# iteration: 70
# Time : 142.4780 seconds
#
# iteration: 71
# Time : 142.8076 seconds
#
# iteration: 72
# Time : 142.6138 seconds
#
# iteration: 73
# Time : 142.4468 seconds
#
# iteration: 74
# Time : 142.2954 seconds
#
# iteration: 75
# Time : 142.7623 seconds
#
# iteration: 76
# Time : 142.5659 seconds
#
# iteration: 77
# Time : 142.8912 seconds
#
# iteration: 78
# Time : 142.9002 seconds
#
# iteration: 79
# Time : 143.6843 seconds
#
# iteration: 80
# Time : 142.6039 seconds
#
# iteration: 81
# Time : 142.2452 seconds
#
# iteration: 82
# Time : 142.6430 seconds
#
# iteration: 83
# Time : 143.0967 seconds
#
# iteration: 84
# Time : 141.9199 seconds
#
# iteration: 85
# Time : 142.1942 seconds
#
# iteration: 86
# Time : 142.8885 seconds
#
# iteration: 87
# Time : 142.9465 seconds
#
# iteration: 88
# Time : 142.5059 seconds
#
# iteration: 89
# Time : 141.9217 seconds
#
# iteration: 90
# Time : 142.2594 seconds
#
# iteration: 91
# Time : 142.1525 seconds
#
# iteration: 92
# Time : 142.6616 seconds
#
# iteration: 93
# Time : 142.0683 seconds
#
# iteration: 94
# Time : 142.7331 seconds
#
# iteration: 95
# Time : 142.1931 seconds
#
# iteration: 96
# Time : 141.9143 seconds
#
# iteration: 97
# Time : 141.7042 seconds
#
# iteration: 98
# Time : 142.3466 seconds
#
# iteration: 99
# Time : 143.3155 seconds
#
# iteration: 100
# Time : 141.7278 seconds
#
# iteration: 101
# Time : 141.7610 seconds
#
# iteration: 102
# Time : 142.6231 seconds
#
# iteration: 103
# Time : 142.1308 seconds
#
# iteration: 104
# Time : 142.2952 seconds
#
# iteration: 105
# Time : 142.7742 seconds
#
# iteration: 106
# Time : 141.9571 seconds
#
# iteration: 107
# Time : 141.6645 seconds
#
# iteration: 108
# Time : 142.2211 seconds
#
# iteration: 109
# Time : 141.6923 seconds
#
# iteration: 110
# Time : 141.5523 seconds
#
# iteration: 111
# Time : 141.3786 seconds
#
# iteration: 112
# Time : 141.3627 seconds
#
# iteration: 113
# Time : 141.7507 seconds
#
# iteration: 114
# Time : 142.1241 seconds
#
# iteration: 115
# Time : 141.2797 seconds
#
# iteration: 116
# Time : 141.8967 seconds
#
# iteration: 117
# Time : 141.6602 seconds
#
# iteration: 118
# Time : 142.7466 seconds
#
# iteration: 119
# Time : 141.9272 seconds
#
# iteration: 120
# Time : 141.6959 seconds
#
# iteration: 121
# Time : 141.5051 seconds
#
# iteration: 122
# Time : 142.5040 seconds
#
# iteration: 123
# Time : 141.4760 seconds
#
# iteration: 124
# Time : 142.1146 seconds
#
# iteration: 125
# Time : 141.4118 seconds
#
# iteration: 126
# Time : 142.2813 seconds
#
# iteration: 127
# Time : 141.9279 seconds
#
# iteration: 128
# Time : 140.9594 seconds
#
# iteration: 129
# Time : 141.7615 seconds
#
# iteration: 130
# Time : 141.9743 seconds
#
# iteration: 131
# Time : 141.7291 seconds
#
# iteration: 132
# Time : 141.3400 seconds
#
# iteration: 133
# Time : 140.9037 seconds
#
# iteration: 134
# Time : 140.3825 seconds
#
# iteration: 135
# Time : 140.9297 seconds
#
# iteration: 136
# Time : 141.4761 seconds
#
# iteration: 137
# Time : 141.0810 seconds
#
# iteration: 138
# Time : 140.8056 seconds
#
# iteration: 139
# Time : 140.5209 seconds
#
# iteration: 140
# Time : 140.4034 seconds
#
# iteration: 141
# Time : 140.7041 seconds
#
# iteration: 142
# Time : 140.8384 seconds
#
# iteration: 143
# Time : 141.4695 seconds
#
# iteration: 144
# Time : 141.0819 seconds
#
# iteration: 145
# Time : 140.3127 seconds
#
# iteration: 146
# Time : 141.2647 seconds
#
# iteration: 147
# Time : 140.8572 seconds
#
# iteration: 148
# Time : 140.4319 seconds
#
# iteration: 149
# Time : 141.4065 seconds
#
# iteration: 150
# Time : 141.0708 seconds
#
# iteration: 151
# Time : 140.9616 seconds
#
# iteration: 152
# Time : 140.9221 seconds
#
# iteration: 153
# Time : 140.7375 seconds
#
# iteration: 154
# Time : 140.8186 seconds
#
# iteration: 155
# Time : 140.8351 seconds
#
# iteration: 156
# Time : 140.7878 seconds
#
# iteration: 157
# Time : 140.2415 seconds
#
# iteration: 158
# Time : 141.4746 seconds
#
# iteration: 159
# Time : 140.6865 seconds
#
# iteration: 160
# Time : 140.8067 seconds
#
# iteration: 161
# Time : 140.5293 seconds
#
# iteration: 162
# Time : 140.8685 seconds
#
# iteration: 163
# Time : 140.1903 seconds
#
# iteration: 164
# Time : 140.1709 seconds
#
# iteration: 165
# Time : 140.4832 seconds
#
# iteration: 166
# Time : 140.5671 seconds
#
# iteration: 167
# Time : 141.0468 seconds
#
# iteration: 168
# Time : 141.0292 seconds
#
# iteration: 169
# Time : 140.5475 seconds
#
# iteration: 170
# Time : 140.0589 seconds
#
# iteration: 171
# Time : 140.5317 seconds
#
# iteration: 172
# Time : 140.2781 seconds
#
# iteration: 173
# Time : 140.5507 seconds
#
# iteration: 174
# Time : 140.9933 seconds
#
# iteration: 175
# Time : 140.9205 seconds
#
# iteration: 176
# Time : 141.0777 seconds
#
# iteration: 177
# Time : 140.9017 seconds
#
# iteration: 178
# Time : 140.4884 seconds
#
# iteration: 179
# Time : 140.4397 seconds
#
# iteration: 180
# Time : 140.6382 seconds
#
# iteration: 181
# Time : 141.5809 seconds
#
# iteration: 182
# Time : 140.9180 seconds
#
# iteration: 183
# Time : 140.9995 seconds
#
# iteration: 184
# Time : 140.5962 seconds
#
# iteration: 185
# Time : 140.0519 seconds
#
# iteration: 186
# Time : 140.3868 seconds
#
# iteration: 187
# Time : 140.5298 seconds
#
# iteration: 188
# Time : 141.1430 seconds
#
# iteration: 189
# Time : 141.2644 seconds
#
# iteration: 190
# Time : 140.9187 seconds
#
# iteration: 191
# Time : 141.2973 seconds
#
# iteration: 192
# Time : 140.8426 seconds
#
# iteration: 193
# Time : 141.1316 seconds
#
# iteration: 194
# Time : 141.6063 seconds
#
# iteration: 195
# Time : 140.8154 seconds
#
# iteration: 196
# Time : 140.2153 seconds
#
# iteration: 197
# Time : 140.1909 seconds
#
# iteration: 198
# Time : 140.8908 seconds
#
# iteration: 199
# Time : 141.0660 seconds
#
# iteration: 200
# Time : 140.7058 seconds

# %% [markdown]
# ## Store model

# %%
model_file_name = "ablima_model_200_iteration"

# %%
with open(f"trained_model/{model_file_name}.pkl", 'wb') as f:
    pickle.dump(trained_model, f)

# %%
dump(trained_model, f"trained_model/{model_file_name}.joblib")
# Out:
# ['trained_model/ablima_model_200_iteration.joblib']
